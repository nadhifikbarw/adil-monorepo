# %% [markdown]
# # Adil Dataset Generator

# %%
import os
import re
import numpy as np
import pandas as pd

# %%
TXT_DIR = "../../adil-dataset/txt-fixed"
CSV_DIR = "../../adil-dataset/csv"

# %%
word_dataset = []
indexes = []

for filename in os.listdir(TXT_DIR):
    if filename.endswith(".txt"):
        with open(os.path.join(TXT_DIR, filename), "r") as f:
            content = f.read()
            content_split = content.split("\n\n")
            word_dataset.append(content_split)
            indexes.append([filename.split(".")[0] for c in content_split])

# %%
np_word_dataset = np.hstack(word_dataset)
np_indexes =  np.hstack(indexes)
print(np_word_dataset.shape)
print(len(np_word_dataset))
print(len(np_indexes))
# print(np_word_dataset)
# Out:
# (125208,)
# 125208
# 125208

# %%
# Strip the blank space in leading and trailing
np_word_dataset = [re.sub(" +", " ", c) for c in np_word_dataset]
np_word_dataset = np.char.lstrip(np_word_dataset)
np_word_dataset = np.char.rstrip(np_word_dataset)

# %%
df = pd.DataFrame({'id': np_indexes, 'content': np_word_dataset})
df
# Out:
#                                       id  \
# 0       11e44c4eb26bdc80ad4e313231363031
# 1       11e44c4eb26bdc80ad4e313231363031
# 2       11e44c4eb26bdc80ad4e313231363031
# 3       11e44c4eb26bdc80ad4e313231363031
# 4       11e44c4eb26bdc80ad4e313231363031
# ...                                  ...
# 125203  11e796c4c9968eb8a97e313434323339
# 125204  11e796c4c9968eb8a97e313434323339
# 125205  11e796c4c9968eb8a97e313434323339
# 125206  11e796c4c9968eb8a97e313434323339
# 125207  11e796c4c9968eb8a97e313434323339
#
#                                                   content
# 0                     LEMBARAN NEGARA\nREPUBLIK INDONESIA
# 1       No.41, 2013 POLITIK. PEMILU. Pengunduran Diri....
# 2       PERATURAN PEMERINTAH REPUBLIK INDONESIA\nNOMOR...
# 3                                                 TENTANG
# 4       TATA CARA PENGUNDURAN DIRI KEPALA DAERAH, WAKI...
# ...                                                   ...
# 125203                               2017, No.182 \n-413-
# 125204                                www.peraturan.go.id
# 125205                                 2017, No.182 -414-
# 125206                                www.peraturan.go.id
# 125207
#
# [125208 rows x 2 columns]

# %%
# Clean the unrecognized word
FORBIDDEN = r"^[0-9]+[0-9]\,|-\s+[0-9]{1,2}\s+-|^$|^www\.| \
            ^http:\/\/|-[0-9]{1,2}-"
indexes = []
for index, values in df["content"].items():
    if re.search(FORBIDDEN, values):
        indexes.append(index)

df = df.drop(indexes)

# %%
df
# Out:
#                                       id  \
# 0       11e44c4eb26bdc80ad4e313231363031
# 1       11e44c4eb26bdc80ad4e313231363031
# 2       11e44c4eb26bdc80ad4e313231363031
# 3       11e44c4eb26bdc80ad4e313231363031
# 4       11e44c4eb26bdc80ad4e313231363031
# ...                                  ...
# 124973  11e796c4c9968eb8a97e313434323339
# 124974  11e796c4c9968eb8a97e313434323339
# 124975  11e796c4c9968eb8a97e313434323339
# 124976  11e796c4c9968eb8a97e313434323339
# 124977  11e796c4c9968eb8a97e313434323339
#
#                                                   content
# 0                     LEMBARAN NEGARA\nREPUBLIK INDONESIA
# 1       No.41, 2013 POLITIK. PEMILU. Pengunduran Diri....
# 2       PERATURAN PEMERINTAH REPUBLIK INDONESIA\nNOMOR...
# 3                                                 TENTANG
# 4       TATA CARA PENGUNDURAN DIRI KEPALA DAERAH, WAKI...
# ...                                                   ...
# 124973                       pada tanggal 16 Agustus 2017
# 124974                MENTERI HUKUM DAN HAK ASASI MANUSIA
# 124975                                REPUBLIK INDONESIA,
# 124976                                                ttd
# 124977                                   YASONNA H. LAOLY
#
# [113950 rows x 2 columns]

# %%
# Clean row that have small amount of letter
reg_section = r"^(pasal)|^(ayat)|^(bab)|^(undang-undang)|^(huruf)|\
                ^(cukup)|^(umum)"

indexes2 = []
for index, values in df["content"].items():
    if len(values) < 7 and not re.search(reg_section, values.lower()):
        indexes2.append(index)

df = df.drop(indexes2)

# %%
df
# Out:
#                                       id  \
# 0       11e44c4eb26bdc80ad4e313231363031
# 1       11e44c4eb26bdc80ad4e313231363031
# 2       11e44c4eb26bdc80ad4e313231363031
# 3       11e44c4eb26bdc80ad4e313231363031
# 4       11e44c4eb26bdc80ad4e313231363031
# ...                                  ...
# 124972  11e796c4c9968eb8a97e313434323339
# 124973  11e796c4c9968eb8a97e313434323339
# 124974  11e796c4c9968eb8a97e313434323339
# 124975  11e796c4c9968eb8a97e313434323339
# 124977  11e796c4c9968eb8a97e313434323339
#
#                                                   content
# 0                     LEMBARAN NEGARA\nREPUBLIK INDONESIA
# 1       No.41, 2013 POLITIK. PEMILU. Pengunduran Diri....
# 2       PERATURAN PEMERINTAH REPUBLIK INDONESIA\nNOMOR...
# 3                                                 TENTANG
# 4       TATA CARA PENGUNDURAN DIRI KEPALA DAERAH, WAKI...
# ...                                                   ...
# 124972                             Diundangkan di Jakarta
# 124973                       pada tanggal 16 Agustus 2017
# 124974                MENTERI HUKUM DAN HAK ASASI MANUSIA
# 124975                                REPUBLIK INDONESIA,
# 124977                                   YASONNA H. LAOLY
#
# [98717 rows x 2 columns]

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                      id  \
# 0      11e44c4eb26bdc80ad4e313231363031
# 1      11e44c4eb26bdc80ad4e313231363031
# 2      11e44c4eb26bdc80ad4e313231363031
# 3      11e44c4eb26bdc80ad4e313231363031
# 4      11e44c4eb26bdc80ad4e313231363031
# ...                                 ...
# 98712  11e796c4c9968eb8a97e313434323339
# 98713  11e796c4c9968eb8a97e313434323339
# 98714  11e796c4c9968eb8a97e313434323339
# 98715  11e796c4c9968eb8a97e313434323339
# 98716  11e796c4c9968eb8a97e313434323339
#
#                                                  content
# 0                    LEMBARAN NEGARA\nREPUBLIK INDONESIA
# 1      No.41, 2013 POLITIK. PEMILU. Pengunduran Diri....
# 2      PERATURAN PEMERINTAH REPUBLIK INDONESIA\nNOMOR...
# 3                                                TENTANG
# 4      TATA CARA PENGUNDURAN DIRI KEPALA DAERAH, WAKI...
# ...                                                  ...
# 98712                             Diundangkan di Jakarta
# 98713                       pada tanggal 16 Agustus 2017
# 98714                MENTERI HUKUM DAN HAK ASASI MANUSIA
# 98715                                REPUBLIK INDONESIA,
# 98716                                   YASONNA H. LAOLY
#
# [98717 rows x 2 columns]

# %%
labels = []
reg_section = r"^(pasal)|^(bab)"
for i, value in df["content"].items():
    if (value.startswith("PERATURAN") \
    or value.startswith("UNDANG-UNDANG")) \
    and "NOMOR" in value:
        labels.append("title")
    elif i > 0 and df["content"][i-1] == "TENTANG":
        labels.append("subtitle")
    elif re.search(reg_section, value.lower()):
        labels.append("section")
    else:
        labels.append("body")
        
len(labels)
# Out:
# 98717

# %%
label_series = pd.Series(labels, name="labels")

# %%
df = pd.concat([df, label_series], axis=1)
df
# Out:
#                                      id  \
# 0      11e44c4eb26bdc80ad4e313231363031
# 1      11e44c4eb26bdc80ad4e313231363031
# 2      11e44c4eb26bdc80ad4e313231363031
# 3      11e44c4eb26bdc80ad4e313231363031
# 4      11e44c4eb26bdc80ad4e313231363031
# ...                                 ...
# 98712  11e796c4c9968eb8a97e313434323339
# 98713  11e796c4c9968eb8a97e313434323339
# 98714  11e796c4c9968eb8a97e313434323339
# 98715  11e796c4c9968eb8a97e313434323339
# 98716  11e796c4c9968eb8a97e313434323339
#
#                                                  content    labels
# 0                    LEMBARAN NEGARA\nREPUBLIK INDONESIA      body
# 1      No.41, 2013 POLITIK. PEMILU. Pengunduran Diri....      body
# 2      PERATURAN PEMERINTAH REPUBLIK INDONESIA\nNOMOR...     title
# 3                                                TENTANG      body
# 4      TATA CARA PENGUNDURAN DIRI KEPALA DAERAH, WAKI...  subtitle
# ...                                                  ...       ...
# 98712                             Diundangkan di Jakarta      body
# 98713                       pada tanggal 16 Agustus 2017      body
# 98714                MENTERI HUKUM DAN HAK ASASI MANUSIA      body
# 98715                                REPUBLIK INDONESIA,      body
# 98716                                   YASONNA H. LAOLY      body
#
# [98717 rows x 3 columns]

# %%
df[df["labels"] == "section"]
# Out:
#                                      id    content   labels
# 18     11e44c4eb26bdc80ad4e313231363031      BAB I  section
# 20     11e44c4eb26bdc80ad4e313231363031    Pasal 1  section
# 29     11e44c4eb26bdc80ad4e313231363031     BAB II  section
# 32     11e44c4eb26bdc80ad4e313231363031    Pasal 2  section
# 35     11e44c4eb26bdc80ad4e313231363031    Pasal 3  section
# ...                                 ...        ...      ...
# 98690  11e796c4c9968eb8a97e313434323339  Pasal 569  section
# 98692  11e796c4c9968eb8a97e313434323339  Pasal 570  section
# 98697  11e796c4c9968eb8a97e313434323339  Pasal 571  section
# 98703  11e796c4c9968eb8a97e313434323339  Pasal 572  section
# 98705  11e796c4c9968eb8a97e313434323339  Pasal 573  section
#
# [17069 rows x 3 columns]

# %%
df.to_csv(CSV_DIR+"/data.csv", index=False)
